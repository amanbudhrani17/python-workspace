# %% [markdown]
# # Data Frames

# %%
import numpy as np
import pandas as pd
from numpy.random import randn

# %%
# Index Levels
outside = ['G1','G1','G1','G2','G2','G2']
inside = [1,2,3,1,2,3]
hier_index = list(zip(outside,inside))
hier_index = pd.MultiIndex.from_tuples(hier_index)

# %%
df = pd.DataFrame(randn(6,2),hier_index,['A','B'])

# %%
df
# Out:
#              A         B
# G1 1  1.910299  0.796910
#    2  1.712654  0.470134
#    3  0.078577 -0.013792
# G2 1 -1.625938 -1.539316
#    2  1.258406  0.743468
#    3 -0.248212 -2.004174

# %%
hier_index
# Out:
# MultiIndex([('G1', 1),
#             ('G1', 2),
#             ('G1', 3),
#             ('G2', 1),
#             ('G2', 2),
#             ('G2', 3)],
#            )

# %%
df.loc['G1']
# Out:
#           A         B
# 1  1.910299  0.796910
# 2  1.712654  0.470134
# 3  0.078577 -0.013792

# %%
df
# Out:
#              A         B
# G1 1  1.910299  0.796910
#    2  1.712654  0.470134
#    3  0.078577 -0.013792
# G2 1 -1.625938 -1.539316
#    2  1.258406  0.743468
#    3 -0.248212 -2.004174

# %%
df.index.names = ['Groups','Num']

# %%
df
# Out:
#                    A         B
# Groups Num
# G1     1    1.910299  0.796910
#        2    1.712654  0.470134
#        3    0.078577 -0.013792
# G2     1   -1.625938 -1.539316
#        2    1.258406  0.743468
#        3   -0.248212 -2.004174

# %%
df.loc['G2'].loc[2]['B']
# Out:
# 0.7434676583924079

# %%
df.xs
# Out:
# <bound method NDFrame.xs of                    A         B
# Groups Num
# G1     1    1.910299  0.796910
#        2    1.712654  0.470134
#        3    0.078577 -0.013792
# G2     1   -1.625938 -1.539316
#        2    1.258406  0.743468
#        3   -0.248212 -2.004174>

# %%
df
# Out:
#                    A         B
# Groups Num
# G1     1    1.910299  0.796910
#        2    1.712654  0.470134
#        3    0.078577 -0.013792
# G2     1   -1.625938 -1.539316
#        2    1.258406  0.743468
#        3   -0.248212 -2.004174

# %%
df.xs(1,level='Num')
# Out:
#                A         B
# Groups
# G1      1.910299  0.796910
# G2     -1.625938 -1.539316

# %% [markdown]
# # Pandas - Missing Data

# %%
df = pd.DataFrame({'A':[1,2,np.nan],
                  'B':[5,np.nan,np.nan],
                  'C':[1,2,3]})

# %%
df
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %%
df.dropna()
# Out:
#      A    B  C
# 0  1.0  5.0  1

# %%
df.dropna(thresh=2)
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2

# %%
df.dropna(thresh=1)
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %%
df.loc[[1,2]]
# Out:
#      A   B  C
# 1  2.0 NaN  2
# 2  NaN NaN  3

# %%
df.fillna(value='f')
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0    f  2
# 2    f    f  3

# %%
df
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %% [markdown]
# # Group By

# %%
  data = {'Company':['GOOG','GOOG','MSFT','MSFT','FB','FB'],
       'Person':['Sam','Charlie','Amy','Vanessa','Carl','Sarah'],
       'Sales':[200,120,340,124,243,350]}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#   Company   Person  Sales
# 0    GOOG      Sam    200
# 1    GOOG  Charlie    120
# 2    MSFT      Amy    340
# 3    MSFT  Vanessa    124
# 4      FB     Carl    243
# 5      FB    Sarah    350

# %%
 b = df.groupby('Company')

# %%
b.mean()
# Out:
#          Sales
# Company
# FB       296.5
# GOOG     160.0
# MSFT     232.0

# %%
b.sum()
# Out:
#          Sales
# Company
# FB         593
# GOOG       320
# MSFT       464

# %%
df
# Out:
#   Company   Person  Sales
# 0    GOOG      Sam    200
# 1    GOOG  Charlie    120
# 2    MSFT      Amy    340
# 3    MSFT  Vanessa    124
# 4      FB     Carl    243
# 5      FB    Sarah    350

# %%
b.std()
# Out:
#               Sales
# Company
# FB        75.660426
# GOOG      56.568542
# MSFT     152.735065

# %%
df.groupby('Company').sum().loc['GOOG']
# Out:
# Sales    320
# Name: GOOG, dtype: int64

# %%
df.groupby('Company').max()
# Out:
#           Person  Sales
# Company
# FB         Sarah    350
# GOOG         Sam    200
# MSFT     Vanessa    340

# %%
df.transpose()
# Out:
#             0        1     2        3     4      5
# Company  GOOG     GOOG  MSFT     MSFT    FB     FB
# Person    Sam  Charlie   Amy  Vanessa  Carl  Sarah
# Sales     200      120   340      124   243    350

# %% [markdown]
# # CONCATINATION

# %%
df1 = pd.DataFrame({'A': ['A0', 'A1', 'A2', 'A3'],
                        'B': ['B0', 'B1', 'B2', 'B3'],
                        'C': ['C0', 'C1', 'C2', 'C3'],
                        'D': ['D0', 'D1', 'D2', 'D3']},
                        index=[0, 1, 2, 3])

# %%
df2 = pd.DataFrame({'A': ['A4', 'A5', 'A6', 'A7'],
                        'B': ['B4', 'B5', 'B6', 'B7'],
                        'C': ['C4', 'C5', 'C6', 'C7'],
                        'D': ['D4', 'D5', 'D6', 'D7']},
                         index=[4, 5, 6, 7])

# %%
df3 = pd.DataFrame({'A': ['A8', 'A9', 'A10', 'A11'],
                        'B': ['B8', 'B9', 'B10', 'B11'],
                        'C': ['C8', 'C9', 'C10', 'C11'],
                        'D': ['D8', 'D9', 'D10', 'D11']},
                        index=[8, 9, 10, 11])

# %%
df1
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3

# %%
df2
# Out:
#     A   B   C   D
# 4  A4  B4  C4  D4
# 5  A5  B5  C5  D5
# 6  A6  B6  C6  D6
# 7  A7  B7  C7  D7

# %%
df3
# Out:
#       A    B    C    D
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %%
pd.concat([df1,df2,df3])
# Out:
#       A    B    C    D
# 0    A0   B0   C0   D0
# 1    A1   B1   C1   D1
# 2    A2   B2   C2   D2
# 3    A3   B3   C3   D3
# 4    A4   B4   C4   D4
# 5    A5   B5   C5   D5
# 6    A6   B6   C6   D6
# 7    A7   B7   C7   D7
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %%
pd.concat([df1,df2,df3],axis = 1)
# Out:
#       A    B    C    D    A    B    C    D    A    B    C    D
# 0    A0   B0   C0   D0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1    A1   B1   C1   D1  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2    A2   B2   C2   D2  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3    A3   B3   C3   D3  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4   NaN  NaN  NaN  NaN   A4   B4   C4   D4  NaN  NaN  NaN  NaN
# 5   NaN  NaN  NaN  NaN   A5   B5   C5   D5  NaN  NaN  NaN  NaN
# 6   NaN  NaN  NaN  NaN   A6   B6   C6   D6  NaN  NaN  NaN  NaN
# 7   NaN  NaN  NaN  NaN   A7   B7   C7   D7  NaN  NaN  NaN  NaN
# 8   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   A8   B8   C8   D8
# 9   NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   A9   B9   C9   D9
# 10  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  A10  B10  C10  D10
# 11  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  A11  B11  C11  D11

# %% [markdown]
#  # Merging

# %%
left = pd.DataFrame({'key': ['K0', 'K1', 'K2', 'K3'],
                     'A': ['A0', 'A1', 'A2', 'A3'],
                     'B': ['B0', 'B1', 'B2', 'B3']})
   
right = pd.DataFrame({'key': ['K0', 'K1', 'K2', 'K3'],
                          'C': ['C0', 'C1', 'C2', 'C3'],
                          'D': ['D0', 'D1', 'D2', 'D3']})

# %%
pd.merge(left,right,on='key')
# Out:
#   key   A   B   C   D
# 0  K0  A0  B0  C0  D0
# 1  K1  A1  B1  C1  D1
# 2  K2  A2  B2  C2  D2
# 3  K3  A3  B3  C3  D3

# %%
left = pd.DataFrame({'key1': ['K0', 'K0', 'K1', 'K2'],
                     'key2': ['K0', 'K1', 'K0', 'K1'],
                        'A': ['A0', 'A1', 'A2', 'A3'],
                        'B': ['B0', 'B1', 'B2', 'B3']})
    
right = pd.DataFrame({'key1': ['K0', 'K1', 'K1', 'K2'],
                               'key2': ['K0', 'K0', 'K0', 'K0'],
                                  'C': ['C0', 'C1', 'C2', 'C3'],
                                  'D': ['D0', 'D1', 'D2', 'D3']})

# %%
pd.merge(left,right,how='outer',left_on='key1',right_on='key2')
# Out:
#   key1_x key2_x   A   B key1_y key2_y    C    D
# 0     K0     K0  A0  B0     K0     K0   C0   D0
# 1     K0     K0  A0  B0     K1     K0   C1   D1
# 2     K0     K0  A0  B0     K1     K0   C2   D2
# 3     K0     K0  A0  B0     K2     K0   C3   D3
# 4     K0     K1  A1  B1     K0     K0   C0   D0
# 5     K0     K1  A1  B1     K1     K0   C1   D1
# 6     K0     K1  A1  B1     K1     K0   C2   D2
# 7     K0     K1  A1  B1     K2     K0   C3   D3
# 8     K1     K0  A2  B2    NaN    NaN  NaN  NaN
# 9     K2     K1  A3  B3    NaN    NaN  NaN  NaN

# %% [markdown]
# # Joining

# %%
left = pd.DataFrame({'A': ['A0', 'A1', 'A2'],
                     'B': ['B0', 'B1', 'B2']},
                      index=['K0', 'K1', 'K2']) 

right = pd.DataFrame({'C': ['C0', 'C2', 'C3'],
                    'D': ['D0', 'D2', 'D3']},
                      index=['K0', 'K2', 'K3'])

# %%
left.join(right)
# Out:
#      A   B    C    D
# K0  A0  B0   C0   D0
# K1  A1  B1  NaN  NaN
# K2  A2  B2   C2   D2

# %%
left
# Out:
#      A   B
# K0  A0  B0
# K1  A1  B1
# K2  A2  B2

# %%
right
# Out:
#      C   D
# K0  C0  D0
# K2  C2  D2
# K3  C3  D3

# %%
left.join(right,how='outer')
# Out:
#       A    B    C    D
# K0   A0   B0   C0   D0
# K1   A1   B1  NaN  NaN
# K2   A2   B2   C2   D2
# K3  NaN  NaN   C3   D3

# %% [markdown]
# # Operations

# %%
df = pd.DataFrame({'col1':[1,2,3,4],'col2':[444,555,666,444],'col3':['abc','def','ghi','xyz']})
df.head()
# Out:
#    col1  col2 col3
# 0     1   444  abc
# 1     2   555  def
# 2     3   666  ghi
# 3     4   444  xyz

# %%
df
# Out:
#    col1  col2 col3
# 0     1   444  abc
# 1     2   555  def
# 2     3   666  ghi
# 3     4   444  xyz

# %%
df.head()
# Out:
#    col1  col2 col3
# 0     1   444  abc
# 1     2   555  def
# 2     3   666  ghi
# 3     4   444  xyz

# %%
df['col2'].unique()
# Out:
# array([444, 555, 666])

# %%
df['col2'].nunique()
# Out:
# 3

# %%
df['col2'].value_counts()
# Out:
# 444    2
# 555    1
# 666    1
# Name: col2, dtype: int64

# %%
df[df['col1']>2]
# Out:
#    col1  col2 col3
# 2     3   666  ghi
# 3     4   444  xyz

# %%
def times2(x):
    return x*2

# %%
df['col1'].apply(times2)
# Out:
# 0    2
# 1    4
# 2    6
# 3    8
# Name: col1, dtype: int64

# %%
df['col2'].apply(lambda x: x*2)
# Out:
# 0     888
# 1    1110
# 2    1332
# 3     888
# Name: col2, dtype: int64

# %%
df.columns
# Out:
# Index(['col1', 'col2', 'col3'], dtype='object')

# %%
df
# Out:
#    col1  col2 col3
# 0     1   444  abc
# 1     2   555  def
# 2     3   666  ghi
# 3     4   444  xyz

# %%
df.sort_values('col2')
# Out:
#    col1  col2 col3
# 0     1   444  abc
# 3     4   444  xyz
# 1     2   555  def
# 2     3   666  ghi

# %%
df['col1'][2]
# Out:
# 3

# %%
df.isnull()
# Out:
#     col1   col2   col3
# 0  False  False  False
# 1  False  False  False
# 2  False  False  False
# 3  False  False  False

# %%
data = {'A':['foo','foo','foo','bar','bar','bar'],
     'B':['one','one','two','two','one','one'],
       'C':['x','y','x','y','x','y'],
       'D':[1,3,2,5,4,1]}

df = pd.DataFrame(data)
df
# Out:
#      A    B  C  D
# 0  foo  one  x  1
# 1  foo  one  y  3
# 2  foo  two  x  2
# 3  bar  two  y  5
# 4  bar  one  x  4
# 5  bar  one  y  1

# %%
df.pivot_table(values='D',index=['A','B'],columns=['C']).fillna('Fuck')
# Out:
# C           x     y
# A   B
# bar one   4.0   1.0
#     two  Fuck   5.0
# foo one   1.0   3.0
#     two   2.0  Fuck

# %%
df
# Out:
#      A    B  C  D
# 0  foo  one  x  1
# 1  foo  one  y  3
# 2  foo  two  x  2
# 3  bar  two  y  5
# 4  bar  one  x  4
# 5  bar  one  y  1

# %% [markdown]
#  # Data Input and Output

# %%
pd.read_csv('example')
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
pd.read_csv('example').pivot_table(values = ['a','b'],index='c',columns = 'd')
# Out:
#       a                    b
# d    3    7    11    15   3    7    11    15
# c
# 2   0.0  NaN  NaN   NaN  1.0  NaN  NaN   NaN
# 6   NaN  4.0  NaN   NaN  NaN  5.0  NaN   NaN
# 10  NaN  NaN  8.0   NaN  NaN  NaN  9.0   NaN
# 14  NaN  NaN  NaN  12.0  NaN  NaN  NaN  13.0

# %%
df = pd.read_csv('example')

# %%
df
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
df.to_csv('My_output', index=False)

# %%
df = pd.read_csv('My_output')

# %%
df
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
a = pd.read_excel('Excel_Sample.xlsx',sheet_name='Sheet1')

# %%
a
# Out:
#    Unnamed: 0   a   b   c   d
# 0           0   0   1   2   3
# 1           1   4   5   6   7
# 2           2   8   9  10  11
# 3           3  12  13  14  15

# %%
a.columns
# Out:
# Index(['Unnamed: 0', 'a', 'b', 'c', 'd'], dtype='object')

# %%
a.drop('Unnamed: 0',axis=1,inplace=True)

# %%
a
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
a.to_excel('Excel2.xlsx',sheet_name='Sheet1')

# %%
pd.read_excel('Excel2.xlsx',sheet_name='Sheet1',index_col='Unnamed: 0')
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
data = pd.read_html('https://www.fdic.gov/resources/resolutions/bank-failures/failed-bank-list/')

# %%
data
# Out:
# [                         Bank NameBank           CityCity StateSt  CertCert  \
#  0                    Almena State Bank             Almena      KS     15426
#  1           First City Bank of Florida  Fort Walton Beach      FL     16748
#  2                 The First State Bank      Barboursville      WV     14361
#  3                   Ericson State Bank            Ericson      NE     18265
#  4     City National Bank of New Jersey             Newark      NJ     21111
#  ..                                 ...                ...     ...       ...
#  558                 Superior Bank, FSB           Hinsdale      IL     32646
#  559                Malta National Bank              Malta      OH      6629
#  560    First Alliance Bank & Trust Co.         Manchester      NH     34264
#  561  National State Bank of Metropolis         Metropolis      IL      3815
#  562                   Bank of Honolulu           Honolulu      HI     21029
#
#                   Acquiring InstitutionAI Closing DateClosing  FundFund
#  0                            Equity Bank    October 23, 2020     10538
#  1              United Fidelity Bank, fsb    October 16, 2020     10537
#  2                         MVB Bank, Inc.       April 3, 2020     10536
#  3             Farmers and Merchants Bank   February 14, 2020     10535
#  4                        Industrial Bank    November 1, 2019     10534
#  ..                                   ...                 ...       ...
#  558                Superior Federal, FSB       July 27, 2001      6004
#  559                    North Valley Bank         May 3, 2001      4648
#  560  Southern New Hampshire Bank & Trust    February 2, 2001      4647
#  561              Banterra Bank of Marion   December 14, 2000      4646
#  562                   Bank of the Orient    October 13, 2000      4645
#
#  [563 rows x 7 columns]]

# %%
type(data[0])
# Out:
# pandas.core.frame.DataFrame

# %%
data[0]
# Out:
#                          Bank NameBank           CityCity StateSt  CertCert  \
# 0                    Almena State Bank             Almena      KS     15426
# 1           First City Bank of Florida  Fort Walton Beach      FL     16748
# 2                 The First State Bank      Barboursville      WV     14361
# 3                   Ericson State Bank            Ericson      NE     18265
# 4     City National Bank of New Jersey             Newark      NJ     21111
# ..                                 ...                ...     ...       ...
# 558                 Superior Bank, FSB           Hinsdale      IL     32646
# 559                Malta National Bank              Malta      OH      6629
# 560    First Alliance Bank & Trust Co.         Manchester      NH     34264
# 561  National State Bank of Metropolis         Metropolis      IL      3815
# 562                   Bank of Honolulu           Honolulu      HI     21029
#
#                  Acquiring InstitutionAI Closing DateClosing  FundFund
# 0                            Equity Bank    October 23, 2020     10538
# 1              United Fidelity Bank, fsb    October 16, 2020     10537
# 2                         MVB Bank, Inc.       April 3, 2020     10536
# 3             Farmers and Merchants Bank   February 14, 2020     10535
# 4                        Industrial Bank    November 1, 2019     10534
# ..                                   ...                 ...       ...
# 558                Superior Federal, FSB       July 27, 2001      6004
# 559                    North Valley Bank         May 3, 2001      4648
# 560  Southern New Hampshire Bank & Trust    February 2, 2001      4647
# 561              Banterra Bank of Marion   December 14, 2000      4646
# 562                   Bank of the Orient    October 13, 2000      4645
#
# [563 rows x 7 columns]

# %%
df = data[0]

# %%
df.transpose()
# Out:
#                                        0                           1    \
# Bank NameBank            Almena State Bank  First City Bank of Florida
# CityCity                            Almena           Fort Walton Beach
# StateSt                                 KS                          FL
# CertCert                             15426                       16748
# Acquiring InstitutionAI        Equity Bank   United Fidelity Bank, fsb
# Closing DateClosing       October 23, 2020            October 16, 2020
# FundFund                             10538                       10537
#
#                                           2                           3    \
# Bank NameBank            The First State Bank          Ericson State Bank
# CityCity                        Barboursville                     Ericson
# StateSt                                    WV                          NE
# CertCert                                14361                       18265
# Acquiring InstitutionAI        MVB Bank, Inc.  Farmers and Merchants Bank
# Closing DateClosing             April 3, 2020           February 14, 2020
# FundFund                                10536                       10535
#
#                                                       4                   5    \
# Bank NameBank            City National Bank of New Jersey       Resolute Bank
# CityCity                                           Newark              Maumee
# StateSt                                                NJ                  OH
# CertCert                                            21111               58317
# Acquiring InstitutionAI                   Industrial Bank  Buckeye State Bank
# Closing DateClosing                      November 1, 2019    October 25, 2019
# FundFund                                            10534               10533
#
#                                                        6    \
# Bank NameBank                        Louisa Community Bank
# CityCity                                            Louisa
# StateSt                                                 KY
# CertCert                                             58112
# Acquiring InstitutionAI  Kentucky Farmers Bank Corporation
# Closing DateClosing                       October 25, 2019
# FundFund                                             10532
#
#                                           7    \
# Bank NameBank            The Enloe State Bank
# CityCity                               Cooper
# StateSt                                    TX
# CertCert                                10716
# Acquiring InstitutionAI    Legend Bank, N. A.
# Closing DateClosing              May 31, 2019
# FundFund                                10531
#
#                                                          8    \
# Bank NameBank            Washington Federal Bank for Savings
# CityCity                                             Chicago
# StateSt                                                   IL
# CertCert                                               30570
# Acquiring InstitutionAI                   Royal Savings Bank
# Closing DateClosing                        December 15, 2017
# FundFund                                               10530
#
#                                                                      9    ...  \
# Bank NameBank            The Farmers and Merchants State Bank of Argonia  ...
# CityCity                                                         Argonia  ...
# StateSt                                                               KS  ...
# CertCert                                                           17719  ...
# Acquiring InstitutionAI                                      Conway Bank  ...
# Closing DateClosing                                     October 13, 2017  ...
# FundFund                                                           10529  ...
#
#                                       553                             554  \
# Bank NameBank                NextBank, NA        Oakwood Deposit Bank Co.
# CityCity                          Phoenix                         Oakwood
# StateSt                                AZ                              OH
# CertCert                            22314                            8966
# Acquiring InstitutionAI       No Acquirer  The State Bank & Trust Company
# Closing DateClosing      February 7, 2002                February 1, 2002
# FundFund                             4653                            4652
#
#                                                       555  \
# Bank NameBank                       Bank of Sierra Blanca
# CityCity                                    Sierra Blanca
# StateSt                                                TX
# CertCert                                            22002
# Acquiring InstitutionAI  The Security State Bank of Pecos
# Closing DateClosing                      January 18, 2002
# FundFund                                             4651
#
#                                                       556  \
# Bank NameBank               Hamilton Bank, NA  En Español
# CityCity                                            Miami
# StateSt                                                FL
# CertCert                                            24382
# Acquiring InstitutionAI  Israel Discount Bank of New York
# Closing DateClosing                      January 11, 2002
# FundFund                                             4650
#
#                                             557                    558  \
# Bank NameBank            Sinclair National Bank     Superior Bank, FSB
# CityCity                               Gravette               Hinsdale
# StateSt                                      AR                     IL
# CertCert                                  34248                  32646
# Acquiring InstitutionAI      Delta Trust & Bank  Superior Federal, FSB
# Closing DateClosing           September 7, 2001          July 27, 2001
# FundFund                                   4649                   6004
#
#                                          559  \
# Bank NameBank            Malta National Bank
# CityCity                               Malta
# StateSt                                   OH
# CertCert                                6629
# Acquiring InstitutionAI    North Valley Bank
# Closing DateClosing              May 3, 2001
# FundFund                                4648
#
#                                                          560  \
# Bank NameBank                First Alliance Bank & Trust Co.
# CityCity                                          Manchester
# StateSt                                                   NH
# CertCert                                               34264
# Acquiring InstitutionAI  Southern New Hampshire Bank & Trust
# Closing DateClosing                         February 2, 2001
# FundFund                                                4647
#
#                                                        561                 562
# Bank NameBank            National State Bank of Metropolis    Bank of Honolulu
# CityCity                                        Metropolis            Honolulu
# StateSt                                                 IL                  HI
# CertCert                                              3815               21029
# Acquiring InstitutionAI            Banterra Bank of Marion  Bank of the Orient
# Closing DateClosing                      December 14, 2000    October 13, 2000
# FundFund                                              4646                4645
#
# [7 rows x 563 columns]

# %%
 df.head()
# Out:
#                       Bank NameBank           CityCity StateSt  CertCert  \
# 0                 Almena State Bank             Almena      KS     15426
# 1        First City Bank of Florida  Fort Walton Beach      FL     16748
# 2              The First State Bank      Barboursville      WV     14361
# 3                Ericson State Bank            Ericson      NE     18265
# 4  City National Bank of New Jersey             Newark      NJ     21111
#
#       Acquiring InstitutionAI Closing DateClosing  FundFund
# 0                 Equity Bank    October 23, 2020     10538
# 1   United Fidelity Bank, fsb    October 16, 2020     10537
# 2              MVB Bank, Inc.       April 3, 2020     10536
# 3  Farmers and Merchants Bank   February 14, 2020     10535
# 4             Industrial Bank    November 1, 2019     10534

# %%
data[0]
# Out:
#                          Bank NameBank           CityCity StateSt  CertCert  \
# 0                    Almena State Bank             Almena      KS     15426
# 1           First City Bank of Florida  Fort Walton Beach      FL     16748
# 2                 The First State Bank      Barboursville      WV     14361
# 3                   Ericson State Bank            Ericson      NE     18265
# 4     City National Bank of New Jersey             Newark      NJ     21111
# ..                                 ...                ...     ...       ...
# 558                 Superior Bank, FSB           Hinsdale      IL     32646
# 559                Malta National Bank              Malta      OH      6629
# 560    First Alliance Bank & Trust Co.         Manchester      NH     34264
# 561  National State Bank of Metropolis         Metropolis      IL      3815
# 562                   Bank of Honolulu           Honolulu      HI     21029
#
#                  Acquiring InstitutionAI Closing DateClosing  FundFund
# 0                            Equity Bank    October 23, 2020     10538
# 1              United Fidelity Bank, fsb    October 16, 2020     10537
# 2                         MVB Bank, Inc.       April 3, 2020     10536
# 3             Farmers and Merchants Bank   February 14, 2020     10535
# 4                        Industrial Bank    November 1, 2019     10534
# ..                                   ...                 ...       ...
# 558                Superior Federal, FSB       July 27, 2001      6004
# 559                    North Valley Bank         May 3, 2001      4648
# 560  Southern New Hampshire Bank & Trust    February 2, 2001      4647
# 561              Banterra Bank of Marion   December 14, 2000      4646
# 562                   Bank of the Orient    October 13, 2000      4645
#
# [563 rows x 7 columns]

# %% [markdown]
# # SQL

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine('sqlite:///:memory:')

# %%
df = pd.read_csv('example')

# %%
df.to_sql('my_table',engine)
# Out:
# 4

# %%
sqldf = pd.read_sql('my_table',engine)

# %%
sqldf
# Out:
#    index   a   b   c   d
# 0      0   0   1   2   3
# 1      1   4   5   6   7
# 2      2   8   9  10  11
# 3      3  12  13  14  15

# %%
sqldf.drop()
