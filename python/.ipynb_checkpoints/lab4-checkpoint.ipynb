# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import random
# %matplotlib inline

# %%
X = [0,1,2,3,1,1.5]

# %%
Y = [1,2,1.5,2,1,2]

# %%
poly = np.polyfit(X,Y,deg=2)

# %%
poly
# Out:
# array([-0.09298246,  0.58052632,  1.02824561])

# %%
plt.plot(Y)

# %%
fig, ax = plt.subplots()
ax.plot(Y, label='Given Result')
ax.plot(np.polyval(poly, X), label='Calculated result')
ax.legend()

# %% [markdown]
# # Q2

# %%
X =list()

# %%
for i in range(6):
    X.append(random.randint(1,3))

# %%
X
# Out:
# [2, 1, 1, 2, 2, 1]

# %%
Y1 = list(map(lambda x: 1.7+ 0.5*x, X))

# %%
Y = Y1
Y
# Out:
# [2.7, 2.2, 3.2, 2.7, 3.2, 3.2]

# %%
m = 0
c = 0
l = 0.001
X = np.asarray(X)
n = float(len(X))
iterations = 3
li = list()
for i in range(iterations):
    y_pred = m*X + c
    cost = sum((Y-y_pred)**2)
    print(cost)
    D_m = -(2/n) * (sum((Y - y_pred) * X))
    D_c = -(2/n) * (sum(Y - y_pred))
    m = m - l*D_m
    c = c - l*D_c
    y_pred = m*X + c
    li.append(y_pred)
# Out:
# 50.14000000000001
# 48.78736961777778
# 47.47191121307918

# %%
li
# Out:
# [array([0.0336    , 0.01966667, 0.04753333, 0.0336    , 0.04753333,
#         0.04753333]),
#  array([0.0667356 , 0.03906289, 0.09440831, 0.0667356 , 0.09440831,
#         0.09440831]),
#  array([0.09941323, 0.05819241, 0.14063404, 0.09941323, 0.14063404,
#         0.14063404])]

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_validate

# %%
for i in range(3):
    Y = [li[i][0],li[i][len(li)-1]]
    plt.plot(Y)
a = [Y1[0],Y1[len(Y1)-1]]

# %%
df = pd.read_csv('diabetes.csv')

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
X = df.drop('Outcome',axis=1)

# %%
y = df['Outcome']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=101)

# %%
from sklearn.linear_model import LogisticRegression

# %%
logmodel = LogisticRegression()

# %%
logmodel.fit(X_train,y_train)
# Out:
# /Users/aman/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
val_X = df.iloc[:77,:8]
val_y = df.iloc[:77, 8]
results = cross_validate(estimator=lm, X=val_X, y=val_y, cv = 5)

# %%
results
# Out:
# {'fit_time': array([0.00714993, 0.00257897, 0.00226998, 0.00193   , 0.00168538]),
#  'score_time': array([0.00231004, 0.00169277, 0.00152969, 0.00127387, 0.00128675]),
#  'test_score': array([-0.54119006, -0.26765494, -0.08417583,  0.13635767, -0.13221704])}

# %%
val_X
# Out:
#     Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0             6      148             72             35        0  33.6
# 1             1       85             66             29        0  26.6
# 2             8      183             64              0        0  23.3
# 3             1       89             66             23       94  28.1
# 4             0      137             40             35      168  43.1
# ..          ...      ...            ...            ...      ...   ...
# 72           13      126             90              0        0  43.4
# 73            4      129             86             20      270  35.1
# 74            1       79             75             30        0  32.0
# 75            1        0             48             20        0  24.7
# 76            7       62             78              0        0  32.6
#
#     DiabetesPedigreeFunction  Age
# 0                      0.627   50
# 1                      0.351   31
# ...
